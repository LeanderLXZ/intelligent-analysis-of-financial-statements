# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import tushare as ts

with open('../../tushare_token.txt', 'r') as f:
    token = f.readline()

ts.set_token(token)
tushare_api = ts.pro_api()

# %matplotlib inline
pd.set_option('display.max_rows', None)
pd.set_option('display.max_columns', None)

# %% [markdown]
# # 股票信息表（包含上市信息）

# %%
df_basic = pd.read_csv('../../data/financial_statements/stock_basic_sheet.csv')
df_basic .head()
# Out:
#      ts_code  symbol  name area industry         fullname  \
# 0  000001.SZ  000001  平安银行   深圳       银行       平安银行股份有限公司
# 1  000002.SZ  000002   万科A   深圳     全国地产       万科企业股份有限公司
# 2  000004.SZ  000004  国农科技   深圳      互联网   深圳中国农大科技股份有限公司
# 3  000005.SZ  000005  世纪星源   深圳     环境保护     深圳世纪星源股份有限公司
# 4  000006.SZ  000006  深振业A   深圳     区域地产  深圳市振业(集团)股份有限公司
#
#                              enname market exchange curr_type list_status  \
# 0            Ping An Bank Co., Ltd.     主板     SZSE       CNY           L
# 1              China Vanke Co.,Ltd.     主板     SZSE       CNY           L
# 2  Shenzhen Cau Technology Co.,Ltd.     主板     SZSE       CNY           L
# 3     Shenzhen Fountain Corporation     主板     SZSE       CNY           L
# 4   Shenzhen Zhenye(Group) Co.,Ltd.     主板     SZSE       CNY           L
#
#    list_date  delist_date is_hs
# 0   19910403          NaN     S
# 1   19910129          NaN     S
# 2   19910114          NaN     N
# 3   19901210          NaN     N
# 4   19920427          NaN     S

# %% [markdown]
# # 最新停牌状态表

# %%
# 股票列表
df_suspended = tushare_api.stock_basic(
    exchange='',
    list_status='P',
    fields='ts_code, symbol, name, area, industry, fullname, enname,'
    'market, exchange, curr_type, list_status, list_date,'
    'delist_date, is_hs')
df_suspended.head()
# Out:
#      ts_code  symbol   name area industry        fullname  \
# 0  000670.SZ  000670  *ST盈方   湖北      元器件     盈方微电子股份有限公司
# 1  000760.SZ  000760  *ST斯太   湖北     汽车配件     斯太尔动力股份有限公司
# 2  000792.SZ  000792  *ST盐湖   青海     化工原料    青海盐湖工业股份有限公司
# 3  000939.SZ  000939  *ST凯迪   湖北     新型电力  凯迪生态环境科技股份有限公司
# 4  000995.SZ  000995  *ST皇台   甘肃       白酒    甘肃皇台酒业股份有限公司
#
#                                               enname market exchange  \
# 0                                  Infotmic Co.,Ltd.     主板     SZSE
# 1                                 Steyr Motors Corp.     主板     SZSE
# 2                Qinghai Salt Lake Industry Co.,Ltd.     主板     SZSE
# 3  Kaidi Ecological and Environmental Technology ...     主板     SZSE
# 4    Gansu Huangtai Wine-Marketing Industry Co.,Ltd.     主板     SZSE
#
#   curr_type list_status list_date delist_date is_hs
# 0       CNY           P  19961217        None     N
# 1       CNY           P  19970627        None     N
# 2       CNY           P  19970904        None     N
# 3       CNY           P  19990923        None     N
# 4       CNY           P  20000807        None     N

# %%
df_suspended.to_csv('../../data/financial_statements/suspended_sheet.csv', index=False)

# %% [markdown]
# # 上市日期表

# %%
df_list_date = df_basic[['ts_code', 'symbol', 'name', 'list_date']]
df_list_date.head()
# Out:
#      ts_code  symbol  name  list_date
# 0  000001.SZ  000001  平安银行   19910403
# 1  000002.SZ  000002   万科A   19910129
# 2  000004.SZ  000004  国农科技   19910114
# 3  000005.SZ  000005  世纪星源   19901210
# 4  000006.SZ  000006  深振业A   19920427

# %%
df_list_date.to_csv('../../data/financial_statements/list_date_sheet.csv', index=False)

# %% [markdown]
# # 利润表

# %%
df_income = pd.read_csv('../../data/financial_statements/income_sheet.csv')
df_income .head()
# Out:
#   code    ts_code    ann_date  f_ann_date  end_date  report_type  comp_type  \
# 0    1  000001.SZ  19970828.0  19970828.0  19970630            1        2.0
# 1    1  000001.SZ  19980312.0  19980312.0  19971231            1        2.0
# 2    1  000001.SZ  19980826.0  19980826.0  19980630            1        2.0
# 3    1  000001.SZ  19990423.0  19990423.0  19981231            1        2.0
# 4    1  000001.SZ  19990717.0  19990717.0  19990630            1        2.0
#
#    basic_eps  diluted_eps  total_revenue       revenue    int_income  \
# 0        NaN          NaN   1.314008e+09  1.314008e+09           NaN
# 1        NaN          NaN   1.869233e+09  1.869233e+09  2.657035e+09
# 2        NaN          NaN   1.294420e+09  1.294420e+09           NaN
# 3        NaN          NaN   1.963738e+09  1.963738e+09  2.532461e+09
# 4        NaN          NaN   1.134698e+09  1.134698e+09           NaN
#
#    prem_earned  comm_income  n_commis_income  n_oth_income  n_oth_b_income  \
# 0          NaN  10243958.09              NaN           NaN             NaN
# 1          NaN  39610404.48      27230402.38  2.194466e+08   -1.423155e+08
# 2          NaN  13854435.68              NaN           NaN             NaN
# 3          NaN  30262407.24      18745419.34  7.232896e+07   -1.332979e+08
# 4          NaN   7346929.20              NaN           NaN             NaN
#
#    prem_income  out_prem  une_prem_reser  reins_income  n_sec_tb_income  \
# 0          NaN       NaN             NaN           NaN              NaN
# 1          NaN       NaN             NaN           NaN              NaN
# 2          NaN       NaN             NaN           NaN              NaN
# 3          NaN       NaN             NaN           NaN              NaN
# 4          NaN       NaN             NaN           NaN              NaN
#
#    n_sec_uw_income  n_asset_mg_income  oth_b_income  fv_value_chg_gain  \
# 0              NaN                NaN           NaN                NaN
# 1              NaN                NaN  3.104657e+07                NaN
# 2              NaN                NaN           NaN                NaN
# 3              NaN                NaN  2.084937e+08                NaN
# 4              NaN                NaN           NaN                NaN
#
#    invest_income  ass_invest_income   forex_gain    total_cogs  oper_cost  \
# 0   1.717474e+08                NaN  10961663.44           NaN        NaN
# 1   3.393484e+08                NaN  22413734.45  9.071480e+08        NaN
# 2   7.072541e+07                NaN   7507331.38           NaN        NaN
# 3   1.848269e+08                NaN  20799898.59  1.113156e+09        NaN
# 4   1.088526e+08                NaN    328567.25           NaN        NaN
#
#         int_exp     comm_exp  biz_tax_surchg      sell_exp     admin_exp  \
# 0           NaN   5213519.46    8.479577e+07  2.088764e+08  6.839735e+06
# 1  1.207841e+09  12380002.10    1.854029e+08  5.338086e+08  5.483830e+08
# 2           NaN   4713625.70    8.580717e+07  2.386380e+08  6.079972e+06
# 3  1.001588e+09  11516987.90    1.915828e+08  5.610858e+08  5.742812e+08
# 4           NaN   3241363.34    8.402025e+07  2.390359e+08  4.796524e+06
#
#        fin_exp  assets_impair_loss  prem_refund  compens_payout  \
# 0   2243028.36                 0.0          NaN             NaN
# 1  13267320.76                 NaN          NaN             NaN
# 2    177251.49                 0.0          NaN             NaN
# 3   4098638.66           5500000.0          NaN             NaN
# 4    717579.34                 0.0          NaN             NaN
#
#    reser_insur_liab  div_payt  reins_exp      oper_exp  compens_payout_refu  \
# 0               NaN       NaN        NaN           NaN                  NaN
# 1               NaN       NaN        NaN  9.071480e+08                  NaN
# 2               NaN       NaN        NaN           NaN                  NaN
# 3               NaN       NaN        NaN  1.113156e+09                  NaN
# 4               NaN       NaN        NaN           NaN                  NaN
#
#    insur_reser_refu  reins_cost_refund  other_bus_cost  operate_profit  \
# 0               NaN                NaN             NaN    5.412425e+08
# 1               NaN                NaN    1.733621e+08    9.620847e+08
# 2               NaN                NaN             NaN    4.352653e+08
# 3               NaN                NaN    3.417916e+08    8.505829e+08
# 4               NaN                NaN             NaN    2.789780e+08
#
#    non_oper_income  non_oper_exp  nca_disploss  total_profit    income_tax  \
# 0       1295892.19    6425328.62           NaN  5.240241e+08  8.037768e+07
# 1       8005756.21    9501351.41           NaN  1.002425e+09  1.401973e+08
# 2       2325747.90    1720196.90           NaN  4.358708e+08  5.796592e+07
# 3      14599067.70    8145256.62           NaN  8.570367e+08  9.279660e+07
# 4       1874095.03    4378753.18           NaN  2.764733e+08  3.555473e+07
#
#        n_income  n_income_attr_p  minority_gain  oth_compr_income  \
# 0  4.436464e+08     4.437381e+08      -91666.89               NaN
# 1  8.622279e+08     8.623161e+08      -88247.73               NaN
# 2  3.780131e+08     3.780131e+08            NaN               NaN
# 3  7.642401e+08     7.643392e+08      -99076.40               NaN
# 4  2.409186e+08     2.409186e+08            NaN               NaN
#
#    t_compr_income  compr_inc_attr_p  compr_inc_attr_m_s          ebit  \
# 0             NaN               NaN                 NaN  1.008283e+09
# 1             NaN               NaN                 NaN -6.185830e+08
# 2             NaN               NaN                 NaN  9.591817e+08
# 3             NaN               NaN                 NaN -3.763166e+08
# 4             NaN               NaN                 NaN  8.036042e+08
#
#          ebitda  insurance_exp  undist_profit  distable_profit  update_flag
# 0  1.008283e+09            NaN            NaN              NaN            0
# 1 -6.185830e+08            NaN            NaN              NaN            0
# 2  1.016280e+09            NaN            NaN              NaN            0
# 3 -2.210035e+08            NaN    476794360.4     1.241063e+09            0
# 4  8.652244e+08            NaN            NaN              NaN            0

# %%
df_income_null = df_income.groupby('comp_type').apply(lambda x: x.isnull().all())
df_income_null
# Out:
#             code  ts_code  ann_date  f_ann_date  end_date  report_type  \
# comp_type
# 1.0        False    False     False       False     False        False
# 2.0        False    False     False       False     False        False
# 3.0        False    False     False       False     False        False
# 4.0        False    False     False       False     False        False
#
#            comp_type  basic_eps  diluted_eps  total_revenue  revenue  \
# comp_type
# 1.0            False      False        False          False    False
# 2.0            False      False        False          False    False
# 3.0            False      False        False          False    False
# 4.0            False      False        False          False    False
#
#            int_income  prem_earned  comm_income  n_commis_income  \
# comp_type
# 1.0             False        False        False            False
# 2.0             False         True        False            False
# 3.0             False        False        False            False
# 4.0             False         True        False            False
#
#            n_oth_income  n_oth_b_income  prem_income  out_prem  \
# comp_type
# 1.0               False           False         True      True
# 2.0               False           False        False      True
# 3.0               False           False        False     False
# 4.0               False           False         True      True
#
#            une_prem_reser  reins_income  n_sec_tb_income  n_sec_uw_income  \
# comp_type
# 1.0                 False          True             True             True
# 2.0                  True          True            False             True
# 3.0                 False         False             True             True
# 4.0                  True          True            False            False
#
#            n_asset_mg_income  oth_b_income  fv_value_chg_gain  invest_income  \
# comp_type
# 1.0                     True         False              False          False
# 2.0                    False         False              False          False
# 3.0                     True         False              False          False
# 4.0                    False         False              False          False
#
#            ass_invest_income  forex_gain  total_cogs  oper_cost  int_exp  \
# comp_type
# 1.0                    False       False       False      False    False
# 2.0                    False       False       False      False    False
# 3.0                    False       False       False      False    False
# 4.0                    False       False       False      False    False
#
#            comm_exp  biz_tax_surchg  sell_exp  admin_exp  fin_exp  \
# comp_type
# 1.0           False           False     False      False    False
# 2.0           False           False     False      False    False
# 3.0           False           False     False      False    False
# 4.0           False           False     False      False    False
#
#            assets_impair_loss  prem_refund  compens_payout  reser_insur_liab  \
# comp_type
# 1.0                     False        False           False             False
# 2.0                     False         True            True              True
# 3.0                     False        False           False             False
# 4.0                     False         True            True             False
#
#            div_payt  reins_exp  oper_exp  compens_payout_refu  \
# comp_type
# 1.0           False      False     False                 True
# 2.0            True       True     False                 True
# 3.0           False      False     False                False
# 4.0            True      False     False                 True
#
#            insur_reser_refu  reins_cost_refund  other_bus_cost  \
# comp_type
# 1.0                    True              False           False
# 2.0                    True               True           False
# 3.0                   False              False           False
# 4.0                    True               True           False
#
#            operate_profit  non_oper_income  non_oper_exp  nca_disploss  \
# comp_type
# 1.0                 False            False         False         False
# 2.0                 False            False         False         False
# 3.0                 False            False         False         False
# 4.0                 False            False         False         False
#
#            total_profit  income_tax  n_income  n_income_attr_p  minority_gain  \
# comp_type
# 1.0               False       False     False            False          False
# 2.0               False       False     False            False          False
# 3.0               False       False     False            False          False
# 4.0               False       False     False            False          False
#
#            oth_compr_income  t_compr_income  compr_inc_attr_p  \
# comp_type
# 1.0                   False           False             False
# 2.0                   False           False             False
# 3.0                   False           False             False
# 4.0                   False           False             False
#
#            compr_inc_attr_m_s   ebit  ebitda  insurance_exp  undist_profit  \
# comp_type
# 1.0                     False  False   False           True          False
# 2.0                     False  False   False          False          False
# 3.0                     False  False   False           True          False
# 4.0                     False  False   False           True          False
#
#            distable_profit  update_flag
# comp_type
# 1.0                  False        False
# 2.0                  False        False
# 3.0                  False        False
# 4.0                  False        False

# %%
df_income_null.to_csv('../../data/null_features/df_income_null_features.csv')

# %%
df_income_null_list = pd.DataFrame(columns=('comp_type', 'null_features'))
for i_comp, r in df_income_null.iterrows():
    null_list = []
    for k in r.keys():
        if r[k]:
            null_list.append(k)
    df_income_null_list = df_income_null_list.append(
          pd.DataFrame({'comp_type': [i_comp], 'null_features': [null_list]}), ignore_index=True)

df_income_null_list
# Out:
#    comp_type                                      null_features
# 0        1.0  [prem_income, out_prem, reins_income, n_sec_tb...
# 1        2.0  [prem_earned, out_prem, une_prem_reser, reins_...
# 2        3.0  [n_sec_tb_income, n_sec_uw_income, n_asset_mg_...
# 3        4.0  [prem_earned, prem_income, out_prem, une_prem_...

# %%
df_income_null_list.to_csv('../../data/null_features/income_null_features_list.csv', index=False)

# %% [markdown]
# # 资产负债表

# %%
df_balance = pd.read_csv('../../data/financial_statements/balance_sheet.csv')
df_balance.head()
# Out:
#   code    ts_code    ann_date  f_ann_date  end_date  report_type  comp_type  \
# 0    1  000001.SZ  19921231.0  19921231.0  19921231            1        2.0
# 1    1  000001.SZ  19940416.0  19940416.0  19931231            1        2.0
# 2    1  000001.SZ  19940830.0  19940830.0  19940630            1        2.0
# 3    1  000001.SZ  19950310.0  19950310.0  19941231            1        2.0
# 4    1  000001.SZ  19950811.0  19950811.0  19950630            1        2.0
#
#     total_share      cap_rese  undistr_porfit  surplus_rese  special_rese  \
# 0  1.348169e+08  2.643907e+08    1.464547e+08           NaN           NaN
# 1  2.694298e+08  4.977235e+08    2.625354e+08  1.749039e+08           NaN
# 2  2.694356e+08  4.977235e+08    5.020915e+08  2.436629e+08           NaN
# 3  4.310686e+08  5.499769e+08    3.752195e+08  2.993431e+08           NaN
# 4  4.310686e+08  5.499769e+08    5.880421e+08  2.950139e+08           NaN
#
#       money_cap   trad_asset  notes_receiv  accounts_receiv    oth_receiv  \
# 0  6.320411e+07          NaN           NaN              NaN           NaN
# 1  1.115580e+08   3617127.91           NaN              NaN           NaN
# 2  1.395527e+08          NaN           NaN     3.953815e+07  7.349836e+08
# 3  2.382906e+08  19383436.23           NaN     5.951364e+07  1.853129e+08
# 4  3.254990e+08  14663436.23           NaN     1.698516e+08           NaN
#
#    prepayment  div_receiv  int_receiv   inventories    amor_exp  \
# 0         NaN         NaN         NaN           NaN         NaN
# 1   1086200.0         NaN         NaN  4.234107e+08  3124293.00
# 2         NaN         NaN         NaN           NaN         NaN
# 3    250000.0         NaN         NaN  4.816629e+08  6812085.36
# 4    310000.0         NaN         NaN  4.939842e+08  2943435.45
#
#    nca_within_1y  sett_rsrv  loanto_oth_bank_fi  premium_receiv  \
# 0            NaN        NaN                 NaN             NaN
# 1            NaN        NaN                 NaN             NaN
# 2            NaN        NaN                 NaN             NaN
# 3            NaN        NaN                 NaN             NaN
# 4            NaN        NaN                 NaN             NaN
#
#    reinsur_receiv  reinsur_res_receiv  pur_resale_fa  oth_cur_assets  \
# 0             NaN                 NaN            NaN             NaN
# 1             NaN                 NaN            NaN             NaN
# 2             NaN                 NaN            NaN             NaN
# 3             NaN                 NaN            NaN             NaN
# 4             NaN                 NaN            NaN             NaN
#
#    total_cur_assets  fa_avail_for_sale  htm_invest  lt_eqt_invest  \
# 0      6.320411e+07                NaN         NaN            NaN
# 1      7.845352e+09                NaN         NaN   2.172916e+08
# 2      1.066623e+10                NaN         NaN            NaN
# 3      1.310612e+10                NaN         NaN            NaN
# 4      1.442012e+10                NaN         NaN            NaN
#
#    invest_real_estate  time_deposits  oth_assets  lt_rec  fix_assets  cip  \
# 0                 NaN            NaN         NaN     NaN         NaN  NaN
# 1                 NaN            NaN         NaN     NaN         NaN  NaN
# 2                 NaN            NaN         NaN     NaN         NaN  NaN
# 3                 NaN            NaN         NaN     NaN         NaN  NaN
# 4                 NaN            NaN         NaN     NaN         NaN  NaN
#
#    const_materials  fixed_assets_disp  produc_bio_assets  oil_and_gas_assets  \
# 0              NaN                NaN                NaN                 NaN
# 1              NaN                NaN                NaN                 NaN
# 2              NaN         -241835.00                NaN                 NaN
# 3              NaN                NaN                NaN                 NaN
# 4              NaN            3396.37                NaN                 NaN
#
#    intan_assets  r_and_d  goodwill  lt_amor_exp  defer_tax_assets  \
# 0           NaN      NaN       NaN          NaN               NaN
# 1           NaN      NaN       NaN          NaN               NaN
# 2           NaN      NaN       NaN          NaN               NaN
# 3           NaN      NaN       NaN          NaN               NaN
# 4           NaN      NaN       NaN          NaN               NaN
#
#    decr_in_disbur  oth_nca     total_nca  cash_reser_cb  depos_in_oth_bfi  \
# 0             NaN      NaN  5.720161e+08            NaN               NaN
# 1             NaN      NaN  5.881788e+08            NaN               NaN
# 2             NaN      NaN  2.721473e+08            NaN               NaN
# 3             NaN      NaN  1.209959e+09            NaN               NaN
# 4             NaN      NaN  1.385428e+09            NaN               NaN
#
#    prec_metals  deriv_assets  rr_reins_une_prem  rr_reins_outstd_cla  \
# 0          NaN           NaN                NaN                  NaN
# 1          NaN           NaN                NaN                  NaN
# 2          NaN           NaN                NaN                  NaN
# 3          NaN           NaN                NaN                  NaN
# 4          NaN           NaN                NaN                  NaN
#
#    rr_reins_lins_liab  rr_reins_lthins_liab  refund_depos  ph_pledge_loans  \
# 0                 NaN                   NaN           NaN              NaN
# 1                 NaN                   NaN           NaN              NaN
# 2                 NaN                   NaN           NaN              NaN
# 3                 NaN                   NaN           NaN              NaN
# 4                 NaN                   NaN           NaN              NaN
#
#    refund_cap_depos  indep_acct_assets  client_depos  client_prov  \
# 0               NaN                NaN           NaN          NaN
# 1               NaN                NaN           NaN          NaN
# 2               NaN                NaN           NaN          NaN
# 3               NaN                NaN           NaN          NaN
# 4               NaN                NaN           NaN          NaN
#
#    transac_seat_fee  invest_as_receiv  total_assets  lt_borr     st_borr  \
# 0               NaN               NaN  7.522847e+09      NaN         NaN
# 1               NaN               NaN  9.323224e+09      NaN         NaN
# 2               NaN               NaN  1.246595e+10      NaN         NaN
# 3               NaN               NaN  1.548841e+10      NaN  18150000.0
# 4               NaN               NaN  1.743993e+10      NaN  19350000.0
#
#    cb_borr  depos_ib_deposits  loan_oth_bank  trading_fl  notes_payable  \
# 0      NaN                NaN            NaN         NaN            NaN
# 1      NaN                NaN            NaN         NaN            NaN
# 2      NaN                NaN            NaN         NaN            NaN
# 3      NaN                NaN            NaN         NaN            NaN
# 4      NaN                NaN            NaN         NaN            NaN
#
#    acct_payable  adv_receipts  sold_for_repur_fa  comm_payable  \
# 0           NaN           NaN                NaN           NaN
# 1  3.946385e+07    1898198.05                NaN           NaN
# 2  1.193446e+08           NaN                NaN           NaN
# 3  1.723553e+08           NaN                NaN           NaN
# 4  2.040474e+08   35148248.67                NaN           NaN
#
#    payroll_payable  taxes_payable  int_payable  div_payable   oth_payable  \
# 0              NaN            NaN          NaN          NaN           NaN
# 1       8521020.90    42223199.66          NaN          NaN  6.742463e+07
# 2       5890948.81    50381128.24          NaN          NaN  1.038421e+08
# 3      39155973.28    93159877.73          NaN       433.95  4.729739e+07
# 4      15686583.89    67711561.91          NaN          NaN  8.887981e+07
#
#       acc_exp  deferred_inc  st_bonds_payable  payable_to_reinsurer  \
# 0         NaN           NaN               NaN                   NaN
# 1         NaN           NaN               NaN                   NaN
# 2         NaN           NaN               NaN                   NaN
# 3  3731340.21           NaN               NaN                   NaN
# 4  2142000.00           NaN               NaN                   NaN
#
#    rsrv_insur_cont  acting_trading_sec  acting_uw_sec  non_cur_liab_due_1y  \
# 0              NaN                 NaN            NaN                  NaN
# 1              NaN                 NaN            NaN                  NaN
# 2              NaN                 NaN            NaN                  NaN
# 3              NaN                 NaN            NaN                  NaN
# 4              NaN                 NaN            NaN                  NaN
#
#    oth_cur_liab  total_cur_liab  bond_payable  lt_payable  specific_payables  \
# 0  1.958932e+08    1.958932e+08           NaN         NaN                NaN
# 1           NaN    7.251205e+09           NaN         NaN                NaN
# 2           NaN    9.325414e+09           NaN         NaN                NaN
# 3  1.808641e+05    1.162349e+10           NaN         NaN                NaN
# 4  1.808641e+05    1.251234e+10           NaN         NaN                NaN
#
#    estimated_liab  defer_tax_liab  defer_inc_non_cur_liab  oth_ncl  \
# 0             NaN             NaN                     NaN      NaN
# 1             NaN             NaN                     NaN      NaN
# 2             NaN             NaN                     NaN      NaN
# 3             NaN             NaN                     NaN      NaN
# 4             NaN             NaN                     NaN      NaN
#
#       total_ncl  depos_oth_bfi  deriv_liab  depos  agency_bus_liab  oth_liab  \
# 0           NaN            NaN         NaN    NaN              NaN       NaN
# 1  8.632024e+08            NaN         NaN    NaN              NaN       NaN
# 2  1.627626e+09            NaN         NaN    NaN              NaN       NaN
# 3  2.205090e+09            NaN         NaN    NaN              NaN       NaN
# 4  3.059269e+09            NaN         NaN    NaN              NaN       NaN
#
#    prem_receiv_adva  depos_received  ph_invest  reser_une_prem  \
# 0               NaN             NaN        NaN             NaN
# 1               NaN             NaN        NaN             NaN
# 2               NaN             NaN        NaN             NaN
# 3               NaN             NaN        NaN             NaN
# 4               NaN             NaN        NaN             NaN
#
#    reser_outstd_claims  reser_lins_liab  reser_lthins_liab  indept_acc_liab  \
# 0                  NaN              NaN                NaN              NaN
# 1                  NaN              NaN                NaN              NaN
# 2                  NaN              NaN                NaN              NaN
# 3                  NaN              NaN                NaN              NaN
# 4                  NaN              NaN                NaN              NaN
#
#    pledge_borr  indem_payable  policy_div_payable    total_liab  \
# 0          NaN            NaN                 NaN  1.958932e+08
# 1          NaN            NaN                 NaN  8.114407e+09
# 2          NaN            NaN                 NaN  1.095304e+10
# 3          NaN            NaN                 NaN  1.382858e+10
# 4          NaN            NaN                 NaN  1.557160e+10
#
#    treasury_share  ordin_risk_reser  forex_differ  invest_loss_unconf  \
# 0             NaN               NaN           NaN                 NaN
# 1             NaN               NaN           NaN                 NaN
# 2             NaN               NaN           NaN                 NaN
# 3             NaN               NaN           NaN                 NaN
# 4             NaN               NaN           NaN                 NaN
#
#    minority_int  total_hldr_eqy_exc_min_int  total_hldr_eqy_inc_min_int  \
# 0           NaN                5.456622e+08                5.456622e+08
# 1    4224750.74                1.204580e+09                1.208805e+09
# 2           NaN                1.512913e+09                1.512913e+09
# 3    4224750.74                1.655608e+09                1.659833e+09
# 4    4224750.74                1.864102e+09                1.868326e+09
#
#    total_liab_hldr_eqy  lt_payroll_payable  oth_comp_income  oth_eqt_tools  \
# 0         7.522847e+09                 NaN              NaN            NaN
# 1         9.323224e+09                 NaN              NaN            NaN
# 2         1.246595e+10                 NaN              NaN            NaN
# 3         1.548841e+10                 NaN              NaN            NaN
# 4         1.743993e+10                 NaN              NaN            NaN
#
#    oth_eqt_tools_p_shr  lending_funds  acc_receivable  st_fin_payable  \
# 0                  NaN            NaN             NaN             NaN
# 1                  NaN            NaN             NaN             NaN
# 2                  NaN            NaN             NaN             NaN
# 3                  NaN            NaN             NaN             NaN
# 4                  NaN            NaN             NaN             NaN
#
#    payables  hfs_assets  hfs_sales
# 0       NaN         NaN        NaN
# 1       NaN         NaN        NaN
# 2       NaN         NaN        NaN
# 3       NaN         NaN        NaN
# 4       NaN         NaN        NaN

# %%
df_balance_null = df_balance.groupby('comp_type').apply(lambda x: x.isnull().all())
df_balance_null
# Out:
#             code  ts_code  ann_date  f_ann_date  end_date  report_type  \
# comp_type
# 1.0        False    False     False       False     False        False
# 2.0        False    False     False       False     False        False
# 3.0        False    False     False       False     False        False
# 4.0        False    False     False       False     False        False
#
#            comp_type  total_share  cap_rese  undistr_porfit  surplus_rese  \
# comp_type
# 1.0            False        False     False           False         False
# 2.0            False        False     False           False         False
# 3.0            False        False     False           False         False
# 4.0            False        False     False           False         False
#
#            special_rese  money_cap  trad_asset  notes_receiv  accounts_receiv  \
# comp_type
# 1.0               False      False       False         False            False
# 2.0                True      False       False         False            False
# 3.0               False      False       False         False            False
# 4.0                True      False       False         False            False
#
#            oth_receiv  prepayment  div_receiv  int_receiv  inventories  \
# comp_type
# 1.0             False       False       False       False        False
# 2.0             False       False       False       False        False
# 3.0             False       False       False       False        False
# 4.0             False       False       False       False        False
#
#            amor_exp  nca_within_1y  sett_rsrv  loanto_oth_bank_fi  \
# comp_type
# 1.0           False          False      False               False
# 2.0           False          False      False               False
# 3.0           False          False      False               False
# 4.0           False           True      False               False
#
#            premium_receiv  reinsur_receiv  reinsur_res_receiv  pur_resale_fa  \
# comp_type
# 1.0                 False           False               False          False
# 2.0                  True            True                True          False
# 3.0                 False           False               False          False
# 4.0                 False           False                True          False
#
#            oth_cur_assets  total_cur_assets  fa_avail_for_sale  htm_invest  \
# comp_type
# 1.0                 False             False              False       False
# 2.0                 False             False              False       False
# 3.0                 False             False              False       False
# 4.0                 False             False              False       False
#
#            lt_eqt_invest  invest_real_estate  time_deposits  oth_assets  \
# comp_type
# 1.0                False               False          False       False
# 2.0                False               False          False       False
# 3.0                False               False          False       False
# 4.0                False               False           True       False
#
#            lt_rec  fix_assets    cip  const_materials  fixed_assets_disp  \
# comp_type
# 1.0         False       False  False            False              False
# 2.0         False       False  False             True              False
# 3.0         False       False  False             True              False
# 4.0         False       False  False             True              False
#
#            produc_bio_assets  oil_and_gas_assets  intan_assets  r_and_d  \
# comp_type
# 1.0                    False               False         False    False
# 2.0                     True                True         False     True
# 3.0                     True                True         False     True
# 4.0                     True                True         False    False
#
#            goodwill  lt_amor_exp  defer_tax_assets  decr_in_disbur  oth_nca  \
# comp_type
# 1.0           False        False             False           False    False
# 2.0           False        False             False           False    False
# 3.0           False        False             False           False     True
# 4.0           False        False             False            True    False
#
#            total_nca  cash_reser_cb  depos_in_oth_bfi  prec_metals  \
# comp_type
# 1.0            False          False             False         True
# 2.0            False          False             False        False
# 3.0            False          False             False        False
# 4.0            False          False              True        False
#
#            deriv_assets  rr_reins_une_prem  rr_reins_outstd_cla  \
# comp_type
# 1.0               False               True                 True
# 2.0               False               True                 True
# 3.0               False              False                False
# 4.0               False               True                 True
#
#            rr_reins_lins_liab  rr_reins_lthins_liab  refund_depos  \
# comp_type
# 1.0                      True                  True         False
# 2.0                      True                  True         False
# 3.0                     False                 False         False
# 4.0                      True                  True         False
#
#            ph_pledge_loans  refund_cap_depos  indep_acct_assets  client_depos  \
# comp_type
# 1.0                  False             False               True         False
# 2.0                   True              True               True         False
# 3.0                  False             False              False          True
# 4.0                   True              True               True         False
#
#            client_prov  transac_seat_fee  invest_as_receiv  total_assets  \
# comp_type
# 1.0              False             False             False         False
# 2.0              False              True             False         False
# 3.0               True              True             False         False
# 4.0              False             False             False         False
#
#            lt_borr  st_borr  cb_borr  depos_ib_deposits  loan_oth_bank  \
# comp_type
# 1.0          False    False    False              False          False
# 2.0          False    False    False               True          False
# 3.0          False    False    False              False          False
# 4.0          False    False     True               True          False
#
#            trading_fl  notes_payable  acct_payable  adv_receipts  \
# comp_type
# 1.0             False          False         False         False
# 2.0             False           True         False         False
# 3.0             False           True         False         False
# 4.0             False          False         False         False
#
#            sold_for_repur_fa  comm_payable  payroll_payable  taxes_payable  \
# comp_type
# 1.0                    False         False            False          False
# 2.0                    False          True            False          False
# 3.0                    False         False            False          False
# 4.0                    False         False            False          False
#
#            int_payable  div_payable  oth_payable  acc_exp  deferred_inc  \
# comp_type
# 1.0              False        False        False    False         False
# 2.0              False        False        False    False         False
# 3.0              False        False        False    False         False
# 4.0              False        False        False    False         False
#
#            st_bonds_payable  payable_to_reinsurer  rsrv_insur_cont  \
# comp_type
# 1.0                   False                 False            False
# 2.0                    True                  True             True
# 3.0                    True                 False            False
# 4.0                   False                 False            False
#
#            acting_trading_sec  acting_uw_sec  non_cur_liab_due_1y  \
# comp_type
# 1.0                     False          False                False
# 2.0                     False           True                False
# 3.0                     False          False                False
# 4.0                     False          False                False
#
#            oth_cur_liab  total_cur_liab  bond_payable  lt_payable  \
# comp_type
# 1.0               False           False         False       False
# 2.0               False           False         False       False
# 3.0               False           False         False       False
# 4.0               False           False         False       False
#
#            specific_payables  estimated_liab  defer_tax_liab  \
# comp_type
# 1.0                    False           False           False
# 2.0                     True           False           False
# 3.0                    False           False           False
# 4.0                     True           False           False
#
#            defer_inc_non_cur_liab  oth_ncl  total_ncl  depos_oth_bfi  \
# comp_type
# 1.0                         False    False      False          False
# 2.0                         False    False      False          False
# 3.0                         False    False      False          False
# 4.0                         False    False      False           True
#
#            deriv_liab  depos  agency_bus_liab  oth_liab  prem_receiv_adva  \
# comp_type
# 1.0             False  False            False     False             False
# 2.0             False  False            False     False              True
# 3.0             False  False             True     False             False
# 4.0             False  False            False     False              True
#
#            depos_received  ph_invest  reser_une_prem  reser_outstd_claims  \
# comp_type
# 1.0                 False      False           False                 True
# 2.0                  True       True            True                 True
# 3.0                 False      False           False                False
# 4.0                  True       True            True                 True
#
#            reser_lins_liab  reser_lthins_liab  indept_acc_liab  pledge_borr  \
# comp_type
# 1.0                   True               True             True         True
# 2.0                   True               True             True         True
# 3.0                  False              False            False         True
# 4.0                   True               True             True        False
#
#            indem_payable  policy_div_payable  total_liab  treasury_share  \
# comp_type
# 1.0                False               False       False           False
# 2.0                 True                True       False           False
# 3.0                False               False       False           False
# 4.0                 True                True       False           False
#
#            ordin_risk_reser  forex_differ  invest_loss_unconf  minority_int  \
# comp_type
# 1.0                   False         False               False         False
# 2.0                   False         False                True         False
# 3.0                   False         False                True         False
# 4.0                   False         False                True         False
#
#            total_hldr_eqy_exc_min_int  total_hldr_eqy_inc_min_int  \
# comp_type
# 1.0                             False                       False
# 2.0                             False                       False
# 3.0                             False                       False
# 4.0                             False                       False
#
#            total_liab_hldr_eqy  lt_payroll_payable  oth_comp_income  \
# comp_type
# 1.0                      False               False            False
# 2.0                      False               False            False
# 3.0                      False                True            False
# 4.0                      False               False            False
#
#            oth_eqt_tools  oth_eqt_tools_p_shr  lending_funds  acc_receivable  \
# comp_type
# 1.0                False                False          False           False
# 2.0                False                False           True           False
# 3.0                False                 True           True           False
# 4.0                False                 True          False           False
#
#            st_fin_payable  payables  hfs_assets  hfs_sales
# comp_type
# 1.0                 False     False       False      False
# 2.0                  True     False       False       True
# 3.0                  True     False       False       True
# 4.0                 False     False       False      False

# %%
df_balance_null.to_csv('../../data/null_features/df_balance_null_features.csv')

# %%
df_balance_null_list = pd.DataFrame(columns=('comp_type', 'null_features'))
for i_comp, r in df_balance_null.iterrows():
    null_list = []
    for k in r.keys():
        if r[k]:
            null_list.append(k)
    df_balance_null_list = df_balance_null_list.append(
          pd.DataFrame({'comp_type': [i_comp], 'null_features': [null_list]}), ignore_index=True)
df_balance_null_list
# Out:
#    comp_type                                      null_features
# 0        1.0  [prec_metals, rr_reins_une_prem, rr_reins_outs...
# 1        2.0  [special_rese, premium_receiv, reinsur_receiv,...
# 2        3.0  [const_materials, produc_bio_assets, oil_and_g...
# 3        4.0  [special_rese, nca_within_1y, reinsur_res_rece...

# %%
df_balance_null_list.to_csv('../../data/null_features/balance_null_features_list.csv', index=False)

# %% [markdown]
# # 现金流量表

# %%
df_cashflow = pd.read_csv('../../data/financial_statements/cashflow_sheet.csv')
df_cashflow.head()
# Out:
#   code    ts_code    ann_date  f_ann_date  end_date  comp_type  report_type  \
# 0    1  000001.SZ  20060426.0  20060426.0  20060331          2            1
# 1    1  000001.SZ  20060818.0  20060818.0  20060630          2            1
# 2    1  000001.SZ  20061026.0  20061026.0  20060930          2            1
# 3    1  000001.SZ  20070322.0  20070322.0  20061231          2            1
# 4    1  000001.SZ  20070426.0  20070426.0  20070331          2            1
#
#      net_profit  finan_exp  c_fr_sale_sg  recp_tax_rends  n_depos_incr_fi  \
# 0           NaN        NaN           NaN             NaN              NaN
# 1  4.636207e+08        NaN           NaN             NaN     8.315271e+09
# 2  8.902956e+08        NaN           NaN             NaN     2.128691e+10
# 3  1.302907e+09        NaN           NaN             NaN     3.699054e+10
# 4           NaN        NaN           NaN             NaN     2.017491e+10
#
#    n_incr_loans_cb  n_inc_borr_oth_fi  prem_fr_orig_contr  n_incr_insured_dep  \
# 0              NaN                NaN                 NaN                 NaN
# 1              NaN                NaN                 NaN                 NaN
# 2              NaN       1.810000e+07                 NaN                 NaN
# 3              NaN                NaN                 NaN                 NaN
# 4              NaN      -3.736559e+09                 NaN                 NaN
#
#    n_reinsur_prem  n_incr_disp_tfa  ifc_cash_incr  n_incr_disp_faas  \
# 0             NaN              NaN            NaN               NaN
# 1             NaN              NaN            NaN               NaN
# 2             NaN              NaN   7.505273e+09               NaN
# 3             NaN              NaN   1.034763e+10               NaN
# 4             NaN              NaN   3.146183e+09               NaN
#
#    n_incr_loans_oth_bank  n_cap_incr_repur  c_fr_oth_operate_a  \
# 0                    NaN               NaN        5.482135e+08
# 1                    NaN      1.145795e+10        4.607416e+08
# 2                    NaN               NaN        1.961730e+09
# 3                    NaN               NaN        1.009763e+09
# 4                    NaN               NaN        2.051423e+09
#
#    c_inf_fr_operate_a  c_paid_goods_s  c_paid_to_for_empl  c_paid_for_taxes  \
# 0        1.447810e+10             NaN        3.036651e+08       170203488.0
# 1        2.486822e+10             NaN        5.786818e+08       743273370.0
# 2        3.084382e+10             NaN        8.723329e+08               NaN
# 3        4.948656e+10             NaN        1.230566e+09               NaN
# 4        2.846352e+10             NaN        6.091834e+08       344862458.0
#
#    n_incr_clt_loan_adv  n_incr_dep_cbob  c_pay_claims_orig_inco  \
# 0                  NaN              NaN                     NaN
# 1         2.006744e+10    -8.885204e+08                     NaN
# 2         1.995148e+10     4.685024e+08                     NaN
# 3                  NaN     2.675420e+09                     NaN
# 4                  NaN     3.638747e+09                     NaN
#
#    pay_handling_chrg  pay_comm_insur_plcy  oth_cash_pay_oper_act  \
# 0                NaN                  NaN           3.456765e+08
# 1       2.265120e+09                  NaN           8.009120e+08
# 2       3.619684e+09                  NaN           1.785413e+09
# 3       4.947326e+09                  NaN           1.790982e+09
# 4       1.302907e+09                  NaN           9.100021e+08
#
#    st_cash_out_act  n_cashflow_act  oth_recp_ral_inv_act  \
# 0     8.147715e+08    1.366333e+10                   NaN
# 1     2.213706e+10    2.731155e+09                   NaN
# 2     2.459029e+10    6.253525e+09                   NaN
# 3     4.207617e+10    7.410385e+09                   NaN
# 4     2.474416e+10    3.719364e+09                   NaN
#
#    c_disp_withdrwl_invest  c_recp_return_invest  n_recp_disp_fiolta  \
# 0            2.094553e+10                   NaN                 NaN
# 1                     NaN                   NaN         310489258.0
# 2                     NaN                   NaN         304908947.0
# 3                     NaN                   NaN         363958757.0
# 4                     NaN                   NaN          67299343.0
#
#    n_recp_disp_sobu  stot_inflows_inv_act  c_pay_acq_const_fiolta  \
# 0               NaN          2.111916e+10              36254981.0
# 1               NaN          1.330712e+09              97693239.0
# 2               NaN          1.589356e+09              63568691.0
# 3               NaN          5.112229e+10             249983343.0
# 4               NaN          2.675664e+10             746270777.0
#
#    c_paid_invest  n_disp_subs_oth_biz  oth_pay_ral_inv_act  \
# 0   3.392776e+10                  NaN                  NaN
# 1            NaN                  NaN          202232434.0
# 2            NaN                  NaN         -150647074.0
# 3            NaN                  NaN                  NaN
# 4            NaN                  NaN                  NaN
#
#    n_incr_pledge_loan  stot_out_inv_act  n_cashflow_inv_act  c_recp_borrow  \
# 0                 NaN      3.396402e+10       -1.284486e+10            NaN
# 1                 NaN      9.101454e+09       -7.770742e+09            NaN
# 2                 NaN      9.950768e+09       -8.361412e+09            NaN
# 3                 NaN      5.997183e+10       -8.849543e+09            NaN
# 4                 NaN      3.042915e+10       -3.672515e+09            NaN
#
#    proc_issue_bonds  oth_cash_recp_ral_fnc_act  stot_cash_in_fnc_act  \
# 0               NaN                        NaN                   NaN
# 1               NaN                        NaN                   NaN
# 2               NaN                        NaN                   NaN
# 3               NaN                        NaN                   NaN
# 4               NaN                        NaN                   NaN
#
#    free_cashflow  c_prepay_amt_borr  c_pay_dist_dpcp_int_exp  \
# 0            NaN                NaN                      NaN
# 1            NaN                NaN                      NaN
# 2            NaN                NaN                      NaN
# 3            NaN                NaN                      NaN
# 4            NaN                NaN                      NaN
#
#    incl_dvd_profit_paid_sc_ms  oth_cashpay_ral_fnc_act  stot_cashout_fnc_act  \
# 0                         NaN                      NaN                   NaN
# 1                         NaN                      NaN                   NaN
# 2                         NaN                      NaN                   NaN
# 3                         NaN                      NaN             1227269.0
# 4                         NaN                      NaN                   NaN
#
#    n_cash_flows_fnc_act  eff_fx_flu_cash  n_incr_cash_cash_equ  \
# 0                   NaN         558861.0          8.167445e+08
# 1                   NaN      -12976354.0         -5.052563e+09
# 2                   NaN      -26724697.0         -2.134612e+09
# 3            -1227269.0              NaN         -1.440385e+09
# 4                   NaN              NaN          4.684846e+07
#
#    c_cash_equ_beg_period  c_cash_equ_end_period  c_recp_cap_contrib  \
# 0                    NaN                    NaN                 NaN
# 1                    NaN                    NaN                 NaN
# 2                    NaN                    NaN                 NaN
# 3           1.944790e+10           1.800752e+10                 NaN
# 4           1.800752e+10           1.805436e+10                 NaN
#
#    incl_cash_rec_saims  uncon_invest_loss  prov_depr_assets  \
# 0                  NaN                NaN       340048349.0
# 1                  NaN                NaN       677501998.0
# 2                  NaN                NaN       993140436.0
# 3                  NaN                NaN       796414700.0
# 4                  NaN                NaN               NaN
#
#    depr_fa_coga_dpba  amort_intang_assets  lt_amort_deferred_exp  \
# 0         73781883.0            7078981.0              3866441.0
# 1        147732776.0           11377294.0              8836939.0
# 2        220597733.0           15167126.0             13239923.0
# 3        281505445.0           33567623.0             25047600.0
# 4                NaN                  NaN                    NaN
#
#    decr_deferred_exp  incr_acc_exp  loss_disp_fiolta  loss_scr_fa  \
# 0        -19028651.0    26619935.0               NaN          NaN
# 1         -7494400.0    43698540.0       -56377178.0          NaN
# 2        -17840462.0    32942923.0       -56611288.0          NaN
# 3                NaN           NaN       -59927542.0          NaN
# 4                NaN           NaN               NaN          NaN
#
#    loss_fv_chg  invest_loss  decr_def_inc_tax_assets  incr_def_inc_tax_liab  \
# 0          NaN -176305078.0                      NaN                    NaN
# 1   23961186.0 -457083994.0                      NaN                    NaN
# 2   -2694666.0 -690617600.0                      NaN                    NaN
# 3    4928960.0 -990846089.0               -1754653.0            -14787193.0
# 4          NaN          NaN                      NaN                    NaN
#
#    decr_inventories  decr_oper_payable  incr_oper_payable     others  \
# 0               NaN       3.131070e+09       1.006508e+10   726211.0
# 1               NaN      -1.773398e+10       1.982734e+10        NaN
# 2               NaN      -1.747751e+10       2.277426e+10        NaN
# 3               NaN      -3.053774e+10       3.629613e+10  2900107.0
# 4               NaN                NaN                NaN        NaN
#
#    im_net_cashflow_oper_act  conv_debt_into_cap  conv_copbonds_due_within_1y  \
# 0              1.366333e+10                 NaN                          NaN
# 1              2.731155e+09                 NaN                          NaN
# 2              6.166820e+09                 NaN                          NaN
# 3              7.138344e+09                 NaN                          NaN
# 4                       NaN                 NaN                          NaN
#
#    fa_fnc_leases  end_bal_cash  beg_bal_cash  end_bal_cash_equ  \
# 0            NaN  8.100602e+08  7.879924e+08      1.945458e+10
# 1            NaN  6.891228e+08  7.879924e+08      1.370621e+10
# 2            NaN  9.666321e+08  7.879924e+08      1.634666e+10
# 3            NaN  1.356269e+10  1.221644e+10      4.444825e+09
# 4            NaN           NaN           NaN               NaN
#
#    beg_bal_cash_equ  im_n_incr_cash_equ
# 0      1.865991e+10        8.167445e+08
# 1      1.865991e+10       -5.052563e+09
# 2      1.865991e+10       -2.134612e+09
# 3      7.231455e+09       -1.440385e+09
# 4               NaN                 NaN

# %%
df_cashflow_null = df_cashflow.groupby('comp_type').apply(lambda x: x.isnull().all())
df_cashflow_null
# Out:
#             code  ts_code  ann_date  f_ann_date  end_date  comp_type  \
# comp_type
# 1          False    False     False       False     False      False
# 2          False    False     False       False     False      False
# 3          False    False     False       False     False      False
# 4          False    False     False       False     False      False
#
#            report_type  net_profit  finan_exp  c_fr_sale_sg  recp_tax_rends  \
# comp_type
# 1                False       False      False         False           False
# 2                False       False      False         False           False
# 3                False       False      False         False           False
# 4                False       False      False         False           False
#
#            n_depos_incr_fi  n_incr_loans_cb  n_inc_borr_oth_fi  \
# comp_type
# 1                    False            False              False
# 2                    False            False              False
# 3                    False            False              False
# 4                     True             True              False
#
#            prem_fr_orig_contr  n_incr_insured_dep  n_reinsur_prem  \
# comp_type
# 1                       False               False           False
# 2                       False               False           False
# 3                       False               False           False
# 4                        True                True            True
#
#            n_incr_disp_tfa  ifc_cash_incr  n_incr_disp_faas  \
# comp_type
# 1                    False          False             False
# 2                    False          False              True
# 3                    False          False              True
# 4                    False          False             False
#
#            n_incr_loans_oth_bank  n_cap_incr_repur  c_fr_oth_operate_a  \
# comp_type
# 1                          False             False               False
# 2                          False             False               False
# 3                           True              True               False
# 4                          False             False               False
#
#            c_inf_fr_operate_a  c_paid_goods_s  c_paid_to_for_empl  \
# comp_type
# 1                       False           False               False
# 2                       False           False               False
# 3                       False           False               False
# 4                       False           False               False
#
#            c_paid_for_taxes  n_incr_clt_loan_adv  n_incr_dep_cbob  \
# comp_type
# 1                     False                False            False
# 2                     False                False            False
# 3                     False                False            False
# 4                     False                False             True
#
#            c_pay_claims_orig_inco  pay_handling_chrg  pay_comm_insur_plcy  \
# comp_type
# 1                           False              False                False
# 2                           False              False                False
# 3                           False              False                False
# 4                            True              False                 True
#
#            oth_cash_pay_oper_act  st_cash_out_act  n_cashflow_act  \
# comp_type
# 1                          False            False           False
# 2                          False            False           False
# 3                          False            False           False
# 4                          False            False           False
#
#            oth_recp_ral_inv_act  c_disp_withdrwl_invest  c_recp_return_invest  \
# comp_type
# 1                         False                   False                 False
# 2                         False                   False                 False
# 3                         False                   False                 False
# 4                         False                   False                 False
#
#            n_recp_disp_fiolta  n_recp_disp_sobu  stot_inflows_inv_act  \
# comp_type
# 1                       False             False                 False
# 2                       False             False                 False
# 3                       False             False                 False
# 4                       False             False                 False
#
#            c_pay_acq_const_fiolta  c_paid_invest  n_disp_subs_oth_biz  \
# comp_type
# 1                           False          False                False
# 2                           False          False                False
# 3                           False          False                False
# 4                           False          False                False
#
#            oth_pay_ral_inv_act  n_incr_pledge_loan  stot_out_inv_act  \
# comp_type
# 1                        False               False             False
# 2                        False               False             False
# 3                        False               False             False
# 4                        False                True             False
#
#            n_cashflow_inv_act  c_recp_borrow  proc_issue_bonds  \
# comp_type
# 1                       False          False             False
# 2                       False          False             False
# 3                       False          False             False
# 4                       False          False             False
#
#            oth_cash_recp_ral_fnc_act  stot_cash_in_fnc_act  free_cashflow  \
# comp_type
# 1                              False                 False          False
# 2                              False                 False          False
# 3                              False                 False          False
# 4                              False                 False          False
#
#            c_prepay_amt_borr  c_pay_dist_dpcp_int_exp  \
# comp_type
# 1                      False                    False
# 2                      False                    False
# 3                      False                    False
# 4                      False                    False
#
#            incl_dvd_profit_paid_sc_ms  oth_cashpay_ral_fnc_act  \
# comp_type
# 1                               False                    False
# 2                               False                    False
# 3                               False                    False
# 4                               False                    False
#
#            stot_cashout_fnc_act  n_cash_flows_fnc_act  eff_fx_flu_cash  \
# comp_type
# 1                         False                 False            False
# 2                         False                 False            False
# 3                         False                 False            False
# 4                         False                 False            False
#
#            n_incr_cash_cash_equ  c_cash_equ_beg_period  c_cash_equ_end_period  \
# comp_type
# 1                         False                  False                  False
# 2                         False                  False                  False
# 3                         False                  False                  False
# 4                         False                  False                  False
#
#            c_recp_cap_contrib  incl_cash_rec_saims  uncon_invest_loss  \
# comp_type
# 1                       False                False              False
# 2                       False                False               True
# 3                       False                False               True
# 4                       False                False               True
#
#            prov_depr_assets  depr_fa_coga_dpba  amort_intang_assets  \
# comp_type
# 1                     False              False                False
# 2                     False              False                False
# 3                     False              False                False
# 4                     False              False                False
#
#            lt_amort_deferred_exp  decr_deferred_exp  incr_acc_exp  \
# comp_type
# 1                          False              False         False
# 2                          False              False         False
# 3                          False              False         False
# 4                          False              False         False
#
#            loss_disp_fiolta  loss_scr_fa  loss_fv_chg  invest_loss  \
# comp_type
# 1                     False        False        False        False
# 2                     False        False        False        False
# 3                     False        False        False        False
# 4                     False        False        False        False
#
#            decr_def_inc_tax_assets  incr_def_inc_tax_liab  decr_inventories  \
# comp_type
# 1                            False                  False             False
# 2                            False                  False             False
# 3                            False                  False             False
# 4                            False                  False             False
#
#            decr_oper_payable  incr_oper_payable  others  \
# comp_type
# 1                      False              False   False
# 2                      False              False   False
# 3                      False              False   False
# 4                      False              False   False
#
#            im_net_cashflow_oper_act  conv_debt_into_cap  \
# comp_type
# 1                             False               False
# 2                             False               False
# 3                             False                True
# 4                             False               False
#
#            conv_copbonds_due_within_1y  fa_fnc_leases  end_bal_cash  \
# comp_type
# 1                                False          False         False
# 2                                 True          False         False
# 3                                 True           True         False
# 4                                False          False         False
#
#            beg_bal_cash  end_bal_cash_equ  beg_bal_cash_equ  \
# comp_type
# 1                 False             False             False
# 2                 False             False             False
# 3                 False             False             False
# 4                 False             False             False
#
#            im_n_incr_cash_equ
# comp_type
# 1                       False
# 2                       False
# 3                       False
# 4                       False

# %%
df_cashflow_null.to_csv('../../data/null_features/df_cashflow_null_features.csv')

# %%
df_cashflow_null_list = pd.DataFrame(columns=('comp_type', 'null_features'))
for i_comp, r in df_cashflow_null.iterrows():
    null_list = []
    for k in r.keys():
        if r[k]:
            null_list.append(k)
    df_cashflow_null_list = df_cashflow_null_list.append(
          pd.DataFrame({'comp_type': [i_comp], 'null_features': [null_list]}), ignore_index=True)
df_cashflow_null_list
# Out:
#   comp_type                                      null_features
# 0         1                                                 []
# 1         2  [n_incr_disp_faas, uncon_invest_loss, conv_cop...
# 2         3  [n_incr_disp_faas, n_incr_loans_oth_bank, n_ca...
# 3         4  [n_depos_incr_fi, n_incr_loans_cb, prem_fr_ori...

# %%
df_cashflow_null_list.to_csv('../../data/null_features/cashflow_null_features_list.csv', index=False)

# %% [markdown]
# # 概念股分类表

# %%
df_concept = pd.read_csv('../../data/financial_statements/concept_sheet.csv')
df_concept.head()
# Out:
#   code   name src
# 0  TS0   密集调研  ts
# 1  TS1  南北船合并  ts
# 2  TS2     5G  ts
# 3  TS3     机场  ts
# 4  TS4    高价股  ts

# %% [markdown]
# # 概念股明细表-按概念排列

# %%
df_concept_c = pd.read_csv('../../data/financial_statements/concept_details_sheet_by_concept.csv')
df_concept_c.head()
# Out:
#    code   id concept_name    ts_code  name  in_date  out_date
# 0   301  TS0         密集调研  000301.SZ  东方盛虹      NaN       NaN
# 1   401  TS0         密集调研  000401.SZ  冀东水泥      NaN       NaN
# 2   932  TS0         密集调研  000932.SZ  华菱钢铁      NaN       NaN
# 3  2013  TS0         密集调研  002013.SZ  中航机电      NaN       NaN
# 4  2106  TS0         密集调研  002106.SZ  莱宝高科      NaN       NaN

# %% [markdown]
# # 概念股明细表-按股票排列

# %%
df_concept_s = pd.read_csv('../../data/financial_statements/concept_details_sheet_by_stocks.csv.csv')
df_concept_s.head()
# Out:
#    code    id concept_name    ts_code  name  in_date  out_date
# 0     1  TS11           银行  000001.SZ  平安银行      NaN       NaN
# 1     1  TS25         MSCI  000001.SZ  平安银行      NaN       NaN
# 2     2  TS13          安邦系  000002.SZ   万科A      NaN       NaN
# 3     2  TS22          白马股  000002.SZ   万科A      NaN       NaN
# 4     2  TS25         MSCI  000002.SZ   万科A      NaN       NaN

# %% [markdown]
# # 财务指标表

# %%
df_indicator = pd.read_csv('../../data/financial_statements/financial_indicator_sheet.csv')
df_indicator.head()
# Out:
#   code    ts_code    ann_date  end_date   eps  dt_eps  total_revenue_ps  \
# 0    1  000001.SZ  19900321.0  19891231   NaN     NaN               NaN
# 1    1  000001.SZ  19901231.0  19901231   NaN     NaN               NaN
# 2    1  000001.SZ  19911231.0  19911231   NaN     NaN            3.7097
# 3    1  000001.SZ  19921231.0  19921231   NaN     NaN            3.5271
# 4    1  000001.SZ  19940416.0  19931231  1.06     NaN            2.2969
#
#    revenue_ps  capital_rese_ps  surplus_rese_ps  undist_profit_ps  extra_item  \
# 0         NaN              NaN           0.6666            1.6053         NaN
# 1         NaN              NaN           0.5018            1.1249         NaN
# 2      3.7097           2.9271           0.8145            1.6646         NaN
# 3      3.5271           1.9611              NaN            1.0863         NaN
# 4      2.2969           1.8473           0.6492            0.9744         NaN
#
#    profit_dedt  gross_margin  current_ratio  quick_ratio  cash_ratio  ar_turn  \
# 0          NaN           NaN          9.610        9.610         NaN      NaN
# 1          NaN           NaN         14.289       14.289         NaN      NaN
# 2          NaN           NaN            NaN          NaN         NaN      NaN
# 3          NaN           NaN            NaN          NaN         NaN      NaN
# 4          NaN           NaN            NaN          NaN         NaN      NaN
#
#    ca_turn  fa_turn  assets_turn     op_income  ebit  ebitda  fcff  fcfe  \
# 0      NaN      NaN          NaN           NaN   NaN     NaN   NaN   NaN
# 1      NaN      NaN          NaN           NaN   NaN     NaN   NaN   NaN
# 2      NaN      NaN        0.092  1.464600e+08   NaN     NaN   NaN   NaN
# 3      NaN      NaN        0.080  2.208980e+08   NaN     NaN   NaN   NaN
# 4      NaN      NaN        0.073  2.951494e+08   NaN     NaN   NaN   NaN
#
#    current_exint  noncurrent_exint  interestdebt  netdebt  tangible_asset  \
# 0            NaN               NaN           NaN      NaN             NaN
# 1            NaN               NaN           NaN      NaN             NaN
# 2            NaN               NaN           NaN      NaN             NaN
# 3            NaN               NaN           NaN      NaN             NaN
# 4            NaN               NaN           NaN      NaN             NaN
#
#    working_capital  networking_capital  invest_capital  retained_earnings  \
# 0              NaN                 NaN             NaN       1.000300e+08
# 1              NaN                 NaN             NaN       1.464700e+08
# 2              NaN                 NaN             NaN       2.236600e+08
# 3              NaN                 NaN             NaN       1.464547e+08
# 4              NaN                 NaN             NaN       4.374393e+08
#
#    diluted2_eps    bps  ocfps  retainedps  cfps  ebit_ps  fcff_ps  fcfe_ps  \
# 0         0.977  3.272    NaN      2.2719   NaN      NaN      NaN      NaN
# 1         0.787  2.627    NaN      1.6267   NaN      NaN      NaN      NaN
# 2           NaN    NaN    NaN      2.4791   NaN      NaN      NaN      NaN
# 3           NaN    NaN    NaN      1.0863   NaN      NaN      NaN      NaN
# 4         1.010  4.470    NaN      1.6236   NaN      NaN      NaN      NaN
#
#    netprofit_margin  grossprofit_margin  cogs_of_sales  expense_of_sales  \
# 0               NaN                 NaN            NaN               NaN
# 1               NaN                 NaN            NaN               NaN
# 2           33.6580                 NaN            NaN               NaN
# 3           36.1948                 NaN            NaN               NaN
# 4           44.1643                 NaN            NaN               NaN
#
#    profit_to_gr  saleexp_to_gr  adminexp_of_gr  finaexp_of_gr  impai_ttm  \
# 0           NaN            NaN             NaN            NaN        NaN
# 1           NaN            NaN             NaN            NaN        NaN
# 2       33.6580            NaN             NaN            NaN        NaN
# 3       36.1948            NaN             NaN            NaN        NaN
# 4       44.1643            NaN             NaN            NaN        NaN
#
#    gc_of_gr  op_of_gr  ebit_of_gr      roe  roe_waa  roe_dt  roa    npta  \
# 0       NaN       NaN         NaN      NaN      NaN     NaN  NaN     NaN
# 1       NaN       NaN         NaN  37.2468      NaN     NaN  NaN  3.0810
# 2       NaN   44.8714         NaN  27.6622      NaN     NaN  NaN  3.0975
# 3       NaN   47.4738         NaN  30.6349      NaN     NaN  NaN  2.8981
# 4       NaN   48.8440         NaN  31.2311      NaN     NaN  NaN  3.2448
#
#    roic  roe_yearly  roa2_yearly  debt_to_assets  assets_to_eqt  \
# 0   NaN         NaN          NaN          2.3685         1.0243
# 1   NaN     37.2468          NaN          1.9279         1.0197
# 2   NaN     27.6622          NaN          1.7736         1.0181
# 3   NaN     30.6349          NaN          2.6040         1.0267
# 4   NaN     31.2311          NaN         87.0343         7.7127
#
#    dp_assets_to_eqt  ca_to_assets  nca_to_assets  tbassets_to_totalassets  \
# 0               NaN           NaN            NaN                      NaN
# 1           12.0894           NaN            NaN                      NaN
# 2            8.9305           NaN            NaN                      NaN
# 3           10.5706           NaN            NaN                      NaN
# 4            9.6250           NaN            NaN                      NaN
#
#    int_to_talcap  eqt_to_talcapital  currentdebt_to_debt  longdeb_to_debt  \
# 0            NaN                NaN                  NaN              NaN
# 1            NaN                NaN                  NaN              NaN
# 2            NaN                NaN                  NaN              NaN
# 3            NaN                NaN                  NaN              NaN
# 4            NaN                NaN                  NaN              NaN
#
#    ocf_to_shortdebt  debt_to_eqt  eqt_to_debt  eqt_to_interestdebt  \
# 0               NaN       0.2765       3.6169                  NaN
# 1               NaN       0.2380       4.2024                  NaN
# 2               NaN       0.1336       7.4836                  NaN
# 3               NaN       0.3590       2.7855                  NaN
# 4               NaN       6.7363       0.1484                  NaN
#
#    tangibleasset_to_debt  tangasset_to_intdebt  tangibleasset_to_netdebt  \
# 0                    NaN                   NaN                       NaN
# 1                    NaN                   NaN                       NaN
# 2                    NaN                   NaN                       NaN
# 3                    NaN                   NaN                       NaN
# 4                    NaN                   NaN                       NaN
#
#    ocf_to_debt  turn_days  roa_yearly  roa_dp  fixed_assets  profit_to_op  \
# 0          NaN        NaN         NaN     NaN  2.161000e+07           NaN
# 1          NaN        NaN      3.0810  3.0810  3.293000e+07           NaN
# 2          NaN        NaN      3.0975  3.0975  8.280000e+07       44.8714
# 3          NaN        NaN      2.8981  2.8981  1.873595e+08       47.4738
# 4          NaN        NaN      3.2448  3.2448  3.517224e+08       48.8440
#
#    q_saleexp_to_gr  q_gc_to_gr  q_roe  q_dt_roe  q_npta  q_ocf_to_sales  \
# 0              NaN         NaN    NaN       NaN     NaN             NaN
# 1              NaN         NaN    NaN       NaN     NaN             NaN
# 2              NaN         NaN    NaN       NaN     NaN             NaN
# 3              NaN         NaN    NaN       NaN     NaN             NaN
# 4              NaN         NaN    NaN       NaN     NaN             NaN
#
#    basic_eps_yoy  dt_eps_yoy  cfps_yoy   op_yoy  ebt_yoy  netprofit_yoy  \
# 0            NaN         NaN       NaN      NaN      NaN            NaN
# 1            NaN         NaN       NaN      NaN  50.1037        64.7490
# 2            NaN         NaN       NaN      NaN  48.2674        58.9418
# 3            NaN         NaN       NaN  50.3150  50.3150        52.7830
# 4            NaN         NaN       NaN  33.9002  33.9002        58.7996
#
#    dt_netprofit_yoy  ocf_yoy  roe_yoy  bps_yoy  assets_yoy   eqt_yoy  tr_yoy  \
# 0               NaN      NaN      NaN      NaN         NaN       NaN     NaN
# 1               NaN      NaN   0.3498 -19.7127     73.5898   64.1746     NaN
# 2               NaN      NaN -34.9586      NaN     49.1667  144.3702     NaN
# 3               NaN      NaN  61.8262      NaN     72.7619   -5.5882  42.075
# 4               NaN      NaN -28.0654      NaN     23.9321  120.7556  30.144
#
#    or_yoy  q_sales_yoy  q_op_qoq  equity_yoy
# 0     NaN          NaN       NaN         NaN
# 1     NaN          NaN       NaN     64.1746
# 2     NaN          NaN       NaN    144.3702
# 3  42.075          NaN       NaN     -5.5882
# 4  30.144          NaN       NaN    120.7556

# %% [markdown]
# # ST状态

# %%
df_st_1 = pd.read_csv('../../data/ST_sheets/ST_sheet_20000101-20091231.csv')
df_st_2 = pd.read_csv('../../data/ST_sheets/ST_sheet_20100101-20191231.csv')
df_st_3 = pd.read_csv('../../data/ST_sheets/ST_sheet_20200101-20200905.csv')

# %%
df_st_2.head()
# Out:
#    Unnamed: 0   tradeDate  ticker tradeAbbrName STflg
# 0           0  2010-01-04       4         *ST国农   *ST
# 1           1  2010-01-05       4         *ST国农   *ST
# 2           2  2010-01-06       4         *ST国农   *ST
# 3           3  2010-01-07       4         *ST国农   *ST
# 4           4  2010-01-08       4         *ST国农   *ST

# %% [markdown]
# # 特征词典

# %%
import xlrd

# %%
wb = xlrd.open_workbook('../../data/data_dict.xlsx')
ws_all = wb.sheet_by_name('全特征')
ws_bs_indu = wb.sheet_by_name('bs_indu')
ws_bs_bank = wb.sheet_by_name('bs_bank') 
ws_bs_secu = wb.sheet_by_name('bs_secu') 
ws_bs_insu = wb.sheet_by_name('bs_insu') 
ws_is_indu = wb.sheet_by_name('is_indu')
ws_is_bank = wb.sheet_by_name('is_bank') 
ws_is_secu = wb.sheet_by_name('is_secu') 
ws_is_insu = wb.sheet_by_name('is_insu')
ws_cf_indu = wb.sheet_by_name('cf_indu')
ws_cf_bank = wb.sheet_by_name('cf_bank') 
ws_cf_secu = wb.sheet_by_name('cf_secu') 
ws_cf_insu = wb.sheet_by_name('cf_insu')

# %%
ws_all.col_values(0, 1)
# Out:
# ['cap_rese',
#  'undistr_porfit',
#  'surplus_rese',
#  'special_rese',
#  'money_cap',
#  'trad_asset',
#  'notes_receiv',
#  'accounts_receiv',
#  'oth_receiv',
#  'prepayment',
#  'div_receiv',
#  'int_receiv',
#  'inventories',
#  'amor_exp',
#  'nca_within_1y',
#  'sett_rsrv',
#  'loanto_oth_bank_fi',
#  'premium_receiv',
#  'reinsur_receiv',
#  'reinsur_res_receiv',
#  'pur_resale_fa',
#  'oth_cur_assets',
#  'total_cur_assets',
#  'fa_avail_for_sale',
#  'htm_invest',
#  'lt_eqt_invest',
#  'invest_real_estate',
#  'time_deposits',
#  'oth_assets',
#  'lt_rec',
#  'fix_assets',
#  'cip',
#  'const_materials',
#  'fixed_assets_disp',
#  'produc_bio_assets',
#  'oil_and_gas_assets',
#  'intan_assets',
#  'r_and_d',
#  'goodwill',
#  'lt_amor_exp',
#  'defer_tax_assets',
#  'decr_in_disbur',
#  'oth_nca',
#  'total_nca',
#  'cash_reser_cb',
#  'depos_in_oth_bfi',
#  'prec_metals',
#  'deriv_assets',
#  'rr_reins_une_prem',
#  'rr_reins_outstd_cla',
#  'rr_reins_lins_liab',
#  'rr_reins_lthins_liab',
#  'refund_depos',
#  'ph_pledge_loans',
#  'refund_cap_depos',
#  'indep_acct_assets',
#  'client_depos',
#  'client_prov',
#  'transac_seat_fee',
#  'invest_as_receiv',
#  'total_assets',
#  'lt_borr',
#  'st_borr',
#  'cb_borr',
#  'depos_ib_deposits',
#  'loan_oth_bank',
#  'trading_fl',
#  'notes_payable',
#  'acct_payable',
#  'adv_receipts',
#  'sold_for_repur_fa',
#  'comm_payable',
#  'payroll_payable',
#  'taxes_payable',
#  'int_payable',
#  'div_payable',
#  'oth_payable',
#  'acc_exp',
#  'deferred_inc',
#  'st_bonds_payable',
#  'payable_to_reinsurer',
#  'rsrv_insur_cont',
#  'acting_trading_sec',
#  'acting_uw_sec',
#  'non_cur_liab_due_1y',
#  'oth_cur_liab',
#  'total_cur_liab',
#  'bond_payable',
#  'lt_payable',
#  'specific_payables',
#  'estimated_liab',
#  'defer_tax_liab',
#  'defer_inc_non_cur_liab',
#  'oth_ncl',
#  'total_ncl',
#  'depos_oth_bfi',
#  'deriv_liab',
#  'depos',
#  'agency_bus_liab',
#  'oth_liab',
#  'prem_receiv_adva',
#  'depos_received',
#  'ph_invest',
#  'reser_une_prem',
#  'reser_outstd_claims',
#  'reser_lins_liab',
#  'reser_lthins_liab',
#  'indept_acc_liab',
#  'pledge_borr',
#  'indem_payable',
#  'policy_div_payable',
#  'total_liab',
#  'treasury_share',
#  'ordin_risk_reser',
#  'forex_differ',
#  'invest_loss_unconf',
#  'minority_int',
#  'total_hldr_eqy_exc_min_int',
#  'total_hldr_eqy_inc_min_int',
#  'total_liab_hldr_eqy',
#  'lt_payroll_payable',
#  'oth_comp_income',
#  'oth_eqt_tools',
#  'oth_eqt_tools_p_shr',
#  'lending_funds',
#  'acc_receivable',
#  'st_fin_payable',
#  'payables',
#  'hfs_assets',
#  'hfs_sales',
#  '利润表',
#  'basic_eps',
#  'diluted_eps',
#  'total_revenue',
#  'revenue',
#  'int_income',
#  'prem_earned',
#  'comm_income',
#  'n_commis_income',
#  'n_oth_income',
#  'n_oth_b_income',
#  'prem_income',
#  'out_prem',
#  'une_prem_reser',
#  'reins_income',
#  'n_sec_tb_income',
#  'n_sec_uw_income',
#  'n_asset_mg_income',
#  'oth_b_income',
#  'fv_value_chg_gain',
#  'invest_income',
#  'ass_invest_income',
#  'forex_gain',
#  'total_cogs',
#  'oper_cost',
#  'int_exp',
#  'comm_exp',
#  'biz_tax_surchg',
#  'sell_exp',
#  'admin_exp',
#  'fin_exp',
#  'assets_impair_loss',
#  'prem_refund',
#  'compens_payout',
#  'reser_insur_liab',
#  'div_payt',
#  'reins_exp',
#  'oper_exp',
#  'compens_payout_refu',
#  'insur_reser_refu',
#  'reins_cost_refund',
#  'other_bus_cost',
#  'operate_profit',
#  'non_oper_income',
#  'non_oper_exp',
#  'nca_disploss',
#  'total_profit',
#  'income_tax',
#  'n_income',
#  'n_income_attr_p',
#  'minority_gain',
#  'oth_compr_income',
#  't_compr_income',
#  'compr_inc_attr_p',
#  'compr_inc_attr_m_s',
#  'ebit',
#  'ebitda',
#  'insurance_exp',
#  'undist_profit',
#  'distable_profit',
#  '现金流量表',
#  'c_fr_sale_sg',
#  'recp_tax_rends',
#  'n_depos_incr_fi',
#  'n_incr_loans_cb',
#  'n_inc_borr_oth_fi',
#  'prem_fr_orig_contr',
#  'n_incr_insured_dep',
#  'n_reinsur_prem',
#  'n_incr_disp_tfa',
#  'ifc_cash_incr',
#  'n_incr_disp_faas',
#  'n_incr_loans_oth_bank',
#  'n_cap_incr_repur',
#  'c_fr_oth_operate_a',
#  'c_inf_fr_operate_a',
#  'c_paid_goods_s',
#  'c_paid_to_for_empl',
#  'c_paid_for_taxes',
#  'n_incr_clt_loan_adv',
#  'n_incr_dep_cbob',
#  'c_pay_claims_orig_inco',
#  'pay_handling_chrg',
#  'pay_comm_insur_plcy',
#  'oth_cash_pay_oper_act',
#  'st_cash_out_act',
#  'n_cashflow_act',
#  'oth_recp_ral_inv_act',
#  'c_disp_withdrwl_invest',
#  'c_recp_return_invest',
#  'n_recp_disp_fiolta',
#  'n_recp_disp_sobu',
#  'stot_inflows_inv_act',
#  'c_pay_acq_const_fiolta',
#  'c_paid_invest',
#  'n_disp_subs_oth_biz',
#  'oth_pay_ral_inv_act',
#  'n_incr_pledge_loan',
#  'stot_out_inv_act',
#  'n_cashflow_inv_act',
#  'c_recp_borrow',
#  'proc_issue_bonds',
#  'oth_cash_recp_ral_fnc_act',
#  'stot_cash_in_fnc_act',
#  'free_cashflow',
#  'c_prepay_amt_borr',
#  'c_pay_dist_dpcp_int_exp',
#  'incl_dvd_profit_paid_sc_ms',
#  'oth_cashpay_ral_fnc_act',
#  'stot_cashout_fnc_act',
#  'n_cash_flows_fnc_act',
#  'eff_fx_flu_cash',
#  'n_incr_cash_cash_equ',
#  'c_cash_equ_beg_period',
#  'c_cash_equ_end_period',
#  'c_recp_cap_contrib',
#  'incl_cash_rec_saims',
#  'uncon_invest_loss',
#  'prov_depr_assets',
#  'depr_fa_coga_dpba',
#  'amort_intang_assets',
#  'lt_amort_deferred_exp',
#  'decr_deferred_exp',
#  'incr_acc_exp',
#  'loss_disp_fiolta',
#  'loss_scr_fa',
#  'loss_fv_chg',
#  'invest_loss',
#  'decr_def_inc_tax_assets',
#  'incr_def_inc_tax_liab',
#  'decr_inventories',
#  'decr_oper_payable',
#  'incr_oper_payable',
#  'others',
#  'im_net_cashflow_oper_act',
#  'conv_debt_into_cap',
#  'conv_copbonds_due_within_1y',
#  'fa_fnc_leases',
#  'end_bal_cash',
#  'beg_bal_cash',
#  'end_bal_cash_equ',
#  'beg_bal_cash_equ',
#  'im_n_incr_cash_equ']

# %%
ws_bs_indu.col_values(2, 3)
# Out:
# ['货币资金',
#  '结算备付金',
#  '拆出资金',
#  '衍生金融资产',
#  '交易性金融资产',
#  '应收票据',
#  '应收账款',
#  '预付款项',
#  '应收保费',
#  '应收分保账款',
#  '应收分保合同准备金',
#  '应收利息',
#  '应收股利',
#  '其他应收款',
#  '买入返售金融资产',
#  '存货',
#  '划分为持有待售的资产',
#  '一年内到期的非流动资产',
#  '其他流动资产',
#  '流动资产的特殊项目',
#  '流动资产的调整金额',
#  '流动资产合计',
#  '发放委托贷款及垫款',
#  '可供出售金融资产',
#  '持有至到期投资',
#  '长期应收款',
#  '长期股权投资',
#  '投资性房地产',
#  '固定资产',
#  '在建工程',
#  '工程物资',
#  '固定资产清理',
#  '生产性生物资产',
#  '油气资产',
#  '无形资产',
#  '研发支出',
#  '商誉',
#  '长期待摊费用',
#  '递延所得税资产',
#  '其他非流动资产',
#  '非流动资产的特殊项目',
#  '非流动资产的调整金额',
#  '非流动资产合计',
#  '资产的特殊项目',
#  '资产的调整金额',
#  '资产总计',
#  '短期借款',
#  '向中央银行借款',
#  '吸收存款',
#  '拆入资金',
#  '交易性金融负债',
#  '衍生金融负债',
#  '应付票据',
#  '应付账款',
#  '预收款项',
#  '卖出回购金融资产款',
#  '应付手续费及佣金',
#  '应付职工薪酬',
#  '应交税费',
#  '应付利息',
#  '应付股利',
#  '其他应付款',
#  '应付分保账款',
#  '保险合同准备金',
#  '代理买卖证券款',
#  '代理承销证券款',
#  '划分为持有待售的负债',
#  '一年内到期的非流动负债',
#  '预提费用',
#  '其他流动负债',
#  '流动负债的特殊项目',
#  '流动负债的调整项目',
#  '流动负债合计',
#  '长期借款',
#  '应付债券',
#  '其中：优先股',
#  '永续债',
#  '长期应付款',
#  '长期应付职工薪酬',
#  '专项应付款',
#  '预计负债',
#  '递延收益',
#  '递延所得税负债',
#  '其他非流动负债',
#  '非流动负债的特殊项目',
#  '非流动负债的调整项目',
#  '非流动负债合计',
#  '负债的特殊项目',
#  '负债的调整金额',
#  '负债合计',
#  '实收资本(或股本)',
#  '其他权益工具',
#  '其中：优先股',
#  '永续债',
#  '资本公积',
#  '减:库存股',
#  '其他综合收益',
#  '专项储备',
#  '盈余公积',
#  '一般风险准备',
#  '未分配利润',
#  '外币报表折算差额',
#  '归属于母公司所有者权益特殊项目',
#  '归属于母公司所有者权益调整金额',
#  '归属于母公司所有者权益合计',
#  '少数股东权益',
#  '所有者权益特殊项目',
#  '所有者权益调整金额',
#  '所有者权益(或股东权益)合计',
#  '负债和所有者权益合计特殊项目',
#  '负债和所有者权益合计调整金额',
#  '负债和所有者权益(或股东权益)总计']
